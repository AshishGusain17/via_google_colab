# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishGusain17/via_google_colab/blob/master/clr_snapshot_combined.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# example of saving models for a snapshot ensemble
from sklearn.datasets import make_blobs
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import Callback
from keras.optimizers import SGD
from keras import backend
from math import pi
from math import cos
from math import floor

from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import *
import numpy as np




from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt



import matplotlib
matplotlib.use("Agg")

# %%
# custom callback class for cyclic LR
class CyclicLR(Callback):

    def __init__(self, base_lr=0.001, max_lr=0.006, step_size=2000., mode='triangular',
                 gamma=1., scale_fn=None, scale_mode='cycle'):
        super(CyclicLR, self).__init__()
        self.base_lr = base_lr
        self.max_lr = max_lr
        self.step_size = step_size
        self.mode = mode
        self.gamma = gamma
        if scale_fn == None:
            if self.mode == 'triangular':
                self.scale_fn = lambda x: 1.
                self.scale_mode = 'cycle'
            elif self.mode == 'triangular2':
                self.scale_fn = lambda x: 1/(2.**(x-1))
                self.scale_mode = 'cycle'
            elif self.mode == 'exp_range':
                self.scale_fn = lambda x: gamma**(x)
                self.scale_mode = 'iterations'
        else:
            self.scale_fn = scale_fn
            self.scale_mode = scale_mode
        self.clr_iterations = 0.
        self.trn_iterations = 0.
        self.history = {}

        self._reset()

    def _reset(self, new_base_lr=None, new_max_lr=None,
               new_step_size=None):
        """Resets cycle iterations.
        Optional boundary/step size adjustment.
        """
        if new_base_lr != None:
            self.base_lr = new_base_lr
        if new_max_lr != None:
            self.max_lr = new_max_lr
        if new_step_size != None:
            self.step_size = new_step_size
        self.clr_iterations = 0.
        
    def clr(self):
        cycle = np.floor(1+self.clr_iterations/(2*self.step_size))
        x = np.abs(self.clr_iterations/self.step_size - 2*cycle + 1)
        if self.scale_mode == 'cycle':
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(cycle)
        else:
            return self.base_lr + (self.max_lr-self.base_lr)*np.maximum(0, (1-x))*self.scale_fn(self.clr_iterations)
        
    def on_train_begin(self, logs={}):
        logs = logs or {}

        if self.clr_iterations == 0:
            K.set_value(self.model.optimizer.lr, self.base_lr)
        else:
            K.set_value(self.model.optimizer.lr, self.clr())        
            
    def on_batch_end(self, epoch, logs=None):
        
        logs = logs or {}
        self.trn_iterations += 1
        self.clr_iterations += 1

        self.history.setdefault('lr', []).append(K.get_value(self.model.optimizer.lr))
        self.history.setdefault('iterations', []).append(self.trn_iterations)

        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        
        K.set_value(self.model.optimizer.lr, self.clr())

# %%
# snapshot ensemble class
class SnapshotEnsemble(Callback):
	# constructor
	def __init__(self, n_epochs, n_cycles, lrate_max, verbose=0):
		self.epochs = n_epochs
		self.cycles = n_cycles
		self.lr_max = lrate_max
		self.lrates = list()

	# save models at the end of each cycle
	def on_epoch_end(self, epoch, logs={}):
		# check if we can save model
		epochs_per_cycle = floor(self.epochs / self.cycles)
		if epoch != 0 and (epoch + 1) % epochs_per_cycle == 0:
			# save model to file
			filename = "snapshot_model_%d.h5" % int((epoch + 1) / epochs_per_cycle)
			self.model.save(filename)
			print('>saved snapshot %s, epoch %d' % (filename, epoch))

# %%
print("[INFO] loading CIFAR-10 data...")
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float")
testX = testX.astype("float")
print(trainX.shape , testX.shape)

# apply mean subtraction to the data
mean = np.mean(trainX, axis=0)
trainX -= mean
testX -= mean

# convert the labels from integers to vectors
lb = LabelBinarizer()
trainY = lb.fit_transform(trainY)
testY = lb.transform(testY)
print(trainY.shape , testY.shape)



# construct the image generator for data augmentation
aug = ImageDataGenerator(width_shift_range=0.1,
	height_shift_range=0.1, horizontal_flip=True,
	fill_mode="nearest")
# Out:
# [INFO] loading CIFAR-10 data...
# (50000, 32, 32, 3) (10000, 32, 32, 3)
# (50000, 10) (10000, 10)

# %%
ct = 0
import keras



m1 = keras.applications.ResNet50(include_top=False,
                  input_shape = (32,32,3),
                  weights = 'imagenet')

model = keras.models.Sequential() 
model.add(m1)

for layer in model.layers:
  ct=ct+1

for layer in model.layers:
  if ct>10:
    layer.trainable = False
  else:
    layer.trainable = True
  ct=ct-1


model.add(keras.layers.Flatten())

model.add(keras.layers.Dense(10, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 1, 1, 2048)        23587712
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                20490
# =================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model.compile(loss="categorical_crossentropy", 
              optimizer='adam',
	          metrics=["accuracy"])

# %%
# initialize the cyclical learning rate callback
print("[INFO] using '{}' method".format("triangular"))
clr = CyclicLR(
	mode = "triangular",
	base_lr = 1e-7,
	max_lr = 1e-2,
	step_size = 8 * (trainX.shape[0] // 64))



# callback for snapshot ensembling
n_epochs = 100                 # number of epochs to be trained
n_cycles = 20                  # number of models to be generated
snapShotEN = SnapshotEnsemble(n_epochs, n_cycles, 0.01)
# Out:
# [INFO] using 'triangular' method

# %%
steps_per_epoch = 24         # number of steps in each epoch

# train the network
print("[INFO] training network...")
H = model.fit(
	x=aug.flow(trainX, trainY, 32),
	validation_data=(testX, testY),
	steps_per_epoch=steps_per_epoch,
	epochs=n_epochs,
	callbacks=[clr,snapShotEN],
	verbose=1)
# Out:
# [INFO] training network...
# Epoch 1/100
# 24/24 [==============================] - 34s 1s/step - loss: 3.5257 - accuracy: 0.0977 - val_loss: 4.3336 - val_accuracy: 0.1062
# Epoch 2/100
# 24/24 [==============================] - 16s 665ms/step - loss: 3.1679 - accuracy: 0.1146 - val_loss: 3.2371 - val_accuracy: 0.1419
# Epoch 3/100
# 24/24 [==============================] - 16s 672ms/step - loss: 2.7506 - accuracy: 0.1927 - val_loss: 2.6129 - val_accuracy: 0.2111
# Epoch 4/100
# 24/24 [==============================] - 16s 666ms/step - loss: 2.3786 - accuracy: 0.2279 - val_loss: 2.2391 - val_accuracy: 0.2802
# Epoch 5/100
# 24/24 [==============================] - 16s 665ms/step - loss: 2.0895 - accuracy: 0.3229 - val_loss: 1.9826 - val_accuracy: 0.3447
# >saved snapshot snapshot_model_1.h5, epoch 4
# Epoch 6/100
# 24/24 [==============================] - 16s 683ms/step - loss: 1.8873 - accuracy: 0.3659 - val_loss: 2.0594 - val_accuracy: 0.3868
# Epoch 7/100
# 24/24 [==============================] - 16s 667ms/step - loss: 1.7441 - accuracy: 0.4323 - val_loss: 2.0957 - val_accuracy: 0.4361
# Epoch 8/100
# 24/24 [==============================] - 16s 664ms/step - loss: 1.7311 - accuracy: 0.4635 - val_loss: 1.7703 - val_accuracy: 0.4659
# Epoch 9/100
# 24/24 [==============================] - 16s 660ms/step - loss: 1.7509 - accuracy: 0.4362 - val_loss: 1.6340 - val_accuracy: 0.4838
# Epoch 10/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.6042 - accuracy: 0.4844 - val_loss: 2.3228 - val_accuracy: 0.4930
# >saved snapshot snapshot_model_2.h5, epoch 9
# Epoch 11/100
# 24/24 [==============================] - 16s 667ms/step - loss: 1.5163 - accuracy: 0.4948 - val_loss: 3.0021 - val_accuracy: 0.4973
# Epoch 12/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.4846 - accuracy: 0.5352 - val_loss: 3.4989 - val_accuracy: 0.5172
# Epoch 13/100
# 24/24 [==============================] - 16s 658ms/step - loss: 1.4526 - accuracy: 0.4961 - val_loss: 4.6082 - val_accuracy: 0.5123
# Epoch 14/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.5054 - accuracy: 0.5143 - val_loss: 1.6443 - val_accuracy: 0.5202
# Epoch 15/100
# 24/24 [==============================] - 16s 661ms/step - loss: 1.6365 - accuracy: 0.5052 - val_loss: 7.1575 - val_accuracy: 0.4775
# >saved snapshot snapshot_model_3.h5, epoch 14
# Epoch 16/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.4722 - accuracy: 0.5312 - val_loss: 9.2453 - val_accuracy: 0.4973
# Epoch 17/100
# 24/24 [==============================] - 16s 657ms/step - loss: 1.3871 - accuracy: 0.5742 - val_loss: 4.1636 - val_accuracy: 0.5104
# Epoch 18/100
# 24/24 [==============================] - 16s 663ms/step - loss: 1.3836 - accuracy: 0.5990 - val_loss: 3.7859 - val_accuracy: 0.5465
# Epoch 19/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.6025 - accuracy: 0.5326 - val_loss: 6.7248 - val_accuracy: 0.4336
# Epoch 20/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.7395 - accuracy: 0.4766 - val_loss: 90.8003 - val_accuracy: 0.3202
# >saved snapshot snapshot_model_4.h5, epoch 19
# Epoch 21/100
# 24/24 [==============================] - 16s 664ms/step - loss: 1.8001 - accuracy: 0.4766 - val_loss: 2.6633 - val_accuracy: 0.4380
# Epoch 22/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.6731 - accuracy: 0.4753 - val_loss: 7.2329 - val_accuracy: 0.3320
# Epoch 23/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.9074 - accuracy: 0.4596 - val_loss: 3.3499 - val_accuracy: 0.4193
# Epoch 24/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.8060 - accuracy: 0.4596 - val_loss: 2.8673 - val_accuracy: 0.4008
# Epoch 25/100
# 24/24 [==============================] - 16s 656ms/step - loss: 1.9010 - accuracy: 0.4495 - val_loss: 4.5210 - val_accuracy: 0.3152
# >saved snapshot snapshot_model_5.h5, epoch 24
# Epoch 26/100
# 24/24 [==============================] - 16s 670ms/step - loss: 1.7678 - accuracy: 0.4596 - val_loss: 2.8169 - val_accuracy: 0.3560
# Epoch 27/100
# 24/24 [==============================] - 16s 660ms/step - loss: 1.6795 - accuracy: 0.4479 - val_loss: 20.8788 - val_accuracy: 0.3125
# Epoch 28/100
# 24/24 [==============================] - 16s 657ms/step - loss: 1.6425 - accuracy: 0.4792 - val_loss: 2.4207 - val_accuracy: 0.3940
# Epoch 29/100
# 24/24 [==============================] - 16s 660ms/step - loss: 1.6987 - accuracy: 0.4401 - val_loss: 2.1969 - val_accuracy: 0.4439
# Epoch 30/100
# 24/24 [==============================] - 16s 657ms/step - loss: 1.8481 - accuracy: 0.4831 - val_loss: 37.7232 - val_accuracy: 0.3603
# >saved snapshot snapshot_model_6.h5, epoch 29
# Epoch 31/100
# 24/24 [==============================] - 16s 668ms/step - loss: 2.2312 - accuracy: 0.4505 - val_loss: 180.4802 - val_accuracy: 0.3586
# Epoch 32/100
# 24/24 [==============================] - 16s 658ms/step - loss: 2.2070 - accuracy: 0.4141 - val_loss: 3.7498 - val_accuracy: 0.3353
# Epoch 33/100
# 24/24 [==============================] - 16s 659ms/step - loss: 2.1979 - accuracy: 0.3958 - val_loss: 311.2221 - val_accuracy: 0.1943
# Epoch 34/100
# 24/24 [==============================] - 16s 661ms/step - loss: 2.5814 - accuracy: 0.3008 - val_loss: 7.7192 - val_accuracy: 0.1094
# Epoch 35/100
# 24/24 [==============================] - 16s 659ms/step - loss: 2.7309 - accuracy: 0.2279 - val_loss: 119.6446 - val_accuracy: 0.1006
# >saved snapshot snapshot_model_7.h5, epoch 34
# Epoch 36/100
# 24/24 [==============================] - 16s 664ms/step - loss: 2.7912 - accuracy: 0.1979 - val_loss: 10.2625 - val_accuracy: 0.1104
# Epoch 37/100
# 24/24 [==============================] - 16s 663ms/step - loss: 2.8342 - accuracy: 0.1862 - val_loss: 75.8796 - val_accuracy: 0.0968
# Epoch 38/100
# 24/24 [==============================] - 16s 657ms/step - loss: 2.7402 - accuracy: 0.1641 - val_loss: 753.2222 - val_accuracy: 0.0998
# Epoch 39/100
# 24/24 [==============================] - 16s 661ms/step - loss: 2.4971 - accuracy: 0.1589 - val_loss: 149.2809 - val_accuracy: 0.1034
# Epoch 40/100
# 24/24 [==============================] - 16s 660ms/step - loss: 2.6288 - accuracy: 0.1940 - val_loss: 58309.4509 - val_accuracy: 0.1018
# >saved snapshot snapshot_model_8.h5, epoch 39
# Epoch 41/100
# 24/24 [==============================] - 16s 658ms/step - loss: 2.5765 - accuracy: 0.1849 - val_loss: 33304.0143 - val_accuracy: 0.1057
# Epoch 42/100
# 24/24 [==============================] - 16s 659ms/step - loss: 2.5021 - accuracy: 0.1966 - val_loss: 315.4231 - val_accuracy: 0.1486
# Epoch 43/100
# 24/24 [==============================] - 16s 656ms/step - loss: 2.5814 - accuracy: 0.1589 - val_loss: 46.8153 - val_accuracy: 0.1547
# Epoch 44/100
# 24/24 [==============================] - 16s 659ms/step - loss: 2.6497 - accuracy: 0.1536 - val_loss: 7785.1563 - val_accuracy: 0.1068
# Epoch 45/100
# 24/24 [==============================] - 16s 672ms/step - loss: 2.4268 - accuracy: 0.1940 - val_loss: 5749.0685 - val_accuracy: 0.1001
# >saved snapshot snapshot_model_9.h5, epoch 44
# Epoch 46/100
# 24/24 [==============================] - 16s 665ms/step - loss: 2.4600 - accuracy: 0.2005 - val_loss: 1641.4071 - val_accuracy: 0.1000
# Epoch 47/100
# 24/24 [==============================] - 16s 658ms/step - loss: 2.2723 - accuracy: 0.2214 - val_loss: 1002.5764 - val_accuracy: 0.0985
# Epoch 48/100
# 24/24 [==============================] - 16s 661ms/step - loss: 2.4172 - accuracy: 0.2122 - val_loss: 365.6929 - val_accuracy: 0.1000
# Epoch 49/100
# 24/24 [==============================] - 16s 662ms/step - loss: 2.5803 - accuracy: 0.2057 - val_loss: 417.0004 - val_accuracy: 0.1349
# Epoch 50/100
# 24/24 [==============================] - 16s 655ms/step - loss: 2.4880 - accuracy: 0.2109 - val_loss: 53.5983 - val_accuracy: 0.1509
# >saved snapshot snapshot_model_10.h5, epoch 49
# Epoch 51/100
# 24/24 [==============================] - 16s 667ms/step - loss: 2.2633 - accuracy: 0.2109 - val_loss: 3.6071 - val_accuracy: 0.1913
# Epoch 52/100
# 24/24 [==============================] - 16s 659ms/step - loss: 2.6308 - accuracy: 0.2227 - val_loss: 5.3921 - val_accuracy: 0.2032
# Epoch 53/100
# 24/24 [==============================] - 16s 658ms/step - loss: 2.6571 - accuracy: 0.2044 - val_loss: 31.9372 - val_accuracy: 0.1399
# Epoch 54/100
# 24/24 [==============================] - 16s 658ms/step - loss: 2.3473 - accuracy: 0.2318 - val_loss: 6.4407 - val_accuracy: 0.1954
# Epoch 55/100
# 24/24 [==============================] - 16s 659ms/step - loss: 2.5614 - accuracy: 0.2214 - val_loss: 20.2202 - val_accuracy: 0.2094
# >saved snapshot snapshot_model_11.h5, epoch 54
# Epoch 56/100
# 24/24 [==============================] - 16s 663ms/step - loss: 2.2136 - accuracy: 0.2591 - val_loss: 63.8012 - val_accuracy: 0.2226
# Epoch 57/100
# 24/24 [==============================] - 16s 660ms/step - loss: 2.2526 - accuracy: 0.2565 - val_loss: 138.2539 - val_accuracy: 0.2157
# Epoch 58/100
# 24/24 [==============================] - 16s 661ms/step - loss: 2.2583 - accuracy: 0.2695 - val_loss: 133.9562 - val_accuracy: 0.2528
# Epoch 59/100
# 24/24 [==============================] - 16s 671ms/step - loss: 2.4324 - accuracy: 0.2734 - val_loss: 28.4747 - val_accuracy: 0.2346
# Epoch 60/100
# 24/24 [==============================] - 16s 668ms/step - loss: 2.0737 - accuracy: 0.3060 - val_loss: 15.4455 - val_accuracy: 0.2675
# >saved snapshot snapshot_model_12.h5, epoch 59
# Epoch 61/100
# 24/24 [==============================] - 16s 670ms/step - loss: 2.0502 - accuracy: 0.3060 - val_loss: 14.8315 - val_accuracy: 0.2842
# Epoch 62/100
# 24/24 [==============================] - 16s 662ms/step - loss: 2.1176 - accuracy: 0.3138 - val_loss: 5.6185 - val_accuracy: 0.3166
# Epoch 63/100
# 24/24 [==============================] - 16s 662ms/step - loss: 2.3145 - accuracy: 0.3021 - val_loss: 4.7292 - val_accuracy: 0.3147
# Epoch 64/100
# 24/24 [==============================] - 16s 672ms/step - loss: 1.9159 - accuracy: 0.3190 - val_loss: 11.5974 - val_accuracy: 0.3207
# Epoch 65/100
# 24/24 [==============================] - 16s 654ms/step - loss: 2.3520 - accuracy: 0.3151 - val_loss: 16.3538 - val_accuracy: 0.3211
# >saved snapshot snapshot_model_13.h5, epoch 64
# Epoch 66/100
# 24/24 [==============================] - 16s 659ms/step - loss: 2.2869 - accuracy: 0.3333 - val_loss: 4.7535 - val_accuracy: 0.3635
# Epoch 67/100
# 24/24 [==============================] - 16s 658ms/step - loss: 1.8544 - accuracy: 0.3477 - val_loss: 7.9632 - val_accuracy: 0.3596
# Epoch 68/100
# 24/24 [==============================] - 16s 667ms/step - loss: 2.2034 - accuracy: 0.3581 - val_loss: 3.0324 - val_accuracy: 0.3590
# Epoch 69/100
# 24/24 [==============================] - 16s 666ms/step - loss: 2.0533 - accuracy: 0.3724 - val_loss: 3.9310 - val_accuracy: 0.2922
# Epoch 70/100
# 24/24 [==============================] - 16s 666ms/step - loss: 2.0087 - accuracy: 0.3516 - val_loss: 2.0321 - val_accuracy: 0.3545
# >saved snapshot snapshot_model_14.h5, epoch 69
# Epoch 71/100
# 24/24 [==============================] - 16s 666ms/step - loss: 2.1871 - accuracy: 0.3659 - val_loss: 2.1898 - val_accuracy: 0.3693
# Epoch 72/100
# 24/24 [==============================] - 16s 666ms/step - loss: 2.0459 - accuracy: 0.3372 - val_loss: 17.3316 - val_accuracy: 0.3292
# Epoch 73/100
# 24/24 [==============================] - 16s 668ms/step - loss: 2.3418 - accuracy: 0.3633 - val_loss: 14.1996 - val_accuracy: 0.3577
# Epoch 74/100
# 24/24 [==============================] - 16s 665ms/step - loss: 2.0826 - accuracy: 0.3802 - val_loss: 12.4890 - val_accuracy: 0.3723
# Epoch 75/100
# 24/24 [==============================] - 16s 671ms/step - loss: 2.0219 - accuracy: 0.3385 - val_loss: 2.2997 - val_accuracy: 0.3518
# >saved snapshot snapshot_model_15.h5, epoch 74
# Epoch 76/100
# 24/24 [==============================] - 16s 670ms/step - loss: 1.9524 - accuracy: 0.3789 - val_loss: 5.2675 - val_accuracy: 0.3515
# Epoch 77/100
# 24/24 [==============================] - 16s 665ms/step - loss: 1.9616 - accuracy: 0.3398 - val_loss: 3.0310 - val_accuracy: 0.3712
# Epoch 78/100
# 24/24 [==============================] - 16s 664ms/step - loss: 1.8974 - accuracy: 0.3906 - val_loss: 2.0958 - val_accuracy: 0.3620
# Epoch 79/100
# 24/24 [==============================] - 16s 665ms/step - loss: 1.8345 - accuracy: 0.3672 - val_loss: 3.0310 - val_accuracy: 0.3591
# Epoch 80/100
# 24/24 [==============================] - 16s 669ms/step - loss: 1.8830 - accuracy: 0.3581 - val_loss: 4.3486 - val_accuracy: 0.3936
# >saved snapshot snapshot_model_16.h5, epoch 79
# Epoch 81/100
# 24/24 [==============================] - 16s 664ms/step - loss: 1.9802 - accuracy: 0.3776 - val_loss: 9.0629 - val_accuracy: 0.3011
# Epoch 82/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.6930 - accuracy: 0.3984 - val_loss: 36.6884 - val_accuracy: 0.3393
# Epoch 83/100
# 24/24 [==============================] - 16s 677ms/step - loss: 1.9508 - accuracy: 0.3880 - val_loss: 19.9212 - val_accuracy: 0.3524
# Epoch 84/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.8217 - accuracy: 0.3906 - val_loss: 17.2604 - val_accuracy: 0.3732
# Epoch 85/100
# 24/24 [==============================] - 16s 665ms/step - loss: 1.8246 - accuracy: 0.3737 - val_loss: 115.7227 - val_accuracy: 0.3714
# >saved snapshot snapshot_model_17.h5, epoch 84
# Epoch 86/100
# 24/24 [==============================] - 16s 670ms/step - loss: 1.8512 - accuracy: 0.4245 - val_loss: 186.9761 - val_accuracy: 0.3681
# Epoch 87/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.8467 - accuracy: 0.3633 - val_loss: 29.5400 - val_accuracy: 0.3651
# Epoch 88/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.7209 - accuracy: 0.3945 - val_loss: 2.8446 - val_accuracy: 0.2733
# Epoch 89/100
# 24/24 [==============================] - 16s 663ms/step - loss: 2.1600 - accuracy: 0.3216 - val_loss: 7.1028 - val_accuracy: 0.3092
# Epoch 90/100
# 24/24 [==============================] - 16s 665ms/step - loss: 2.1416 - accuracy: 0.3372 - val_loss: 3.4360 - val_accuracy: 0.3047
# >saved snapshot snapshot_model_18.h5, epoch 89
# Epoch 91/100
# 24/24 [==============================] - 16s 667ms/step - loss: 1.9528 - accuracy: 0.3542 - val_loss: 6.5899 - val_accuracy: 0.3347
# Epoch 92/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.9543 - accuracy: 0.4049 - val_loss: 3.1939 - val_accuracy: 0.3597
# Epoch 93/100
# 24/24 [==============================] - 16s 660ms/step - loss: 1.9116 - accuracy: 0.3789 - val_loss: 1.8502 - val_accuracy: 0.3556
# Epoch 94/100
# 24/24 [==============================] - 16s 662ms/step - loss: 1.7498 - accuracy: 0.3880 - val_loss: 1.7911 - val_accuracy: 0.3508
# Epoch 95/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.8150 - accuracy: 0.3854 - val_loss: 1.6917 - val_accuracy: 0.3668
# >saved snapshot snapshot_model_19.h5, epoch 94
# Epoch 96/100
# 24/24 [==============================] - 16s 659ms/step - loss: 1.7107 - accuracy: 0.3932 - val_loss: 1.7532 - val_accuracy: 0.3554
# Epoch 97/100
# 24/24 [==============================] - 16s 661ms/step - loss: 1.7571 - accuracy: 0.4036 - val_loss: 1.7686 - val_accuracy: 0.3486
# Epoch 98/100
# 24/24 [==============================] - 16s 661ms/step - loss: 1.6920 - accuracy: 0.4102 - val_loss: 1.7131 - val_accuracy: 0.3659
# Epoch 99/100
# 24/24 [==============================] - 16s 656ms/step - loss: 1.7008 - accuracy: 0.3763 - val_loss: 1.8337 - val_accuracy: 0.3537
# Epoch 100/100
# 24/24 [==============================] - 16s 661ms/step - loss: 1.6426 - accuracy: 0.4180 - val_loss: 1.7715 - val_accuracy: 0.3913
# >saved snapshot snapshot_model_20.h5, epoch 99

# %%
import os


print("[INFO] evaluating network...")
predictions = model.predict(x=testX)
print(classification_report(testY.argmax(axis=1) , predictions.argmax(axis=1) , target_names = ["airplane", "automobile", "bird", "cat", "deer", "dog","frog", "horse", "ship", "truck"]))
# Out:
# [INFO] evaluating network...
#               precision    recall  f1-score   support
#
#     airplane       0.36      0.09      0.15      1000
#   automobile       0.35      0.82      0.49      1000
#         bird       0.45      0.07      0.13      1000
#          cat       0.36      0.09      0.15      1000
#         deer       0.37      0.28      0.32      1000
#          dog       0.33      0.47      0.39      1000
#         frog       0.43      0.67      0.53      1000
#        horse       0.56      0.49      0.52      1000
#         ship       0.43      0.46      0.44      1000
#        truck       0.35      0.46      0.40      1000
#
#     accuracy                           0.39     10000
#    macro avg       0.40      0.39      0.35     10000
# weighted avg       0.40      0.39      0.35     10000

# %%
# plot the training and validation accuracy 
N = np.arange(0, n_epochs)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Train and val Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("accuracy.png")

# %%
# plot the training and validation loss  
N = np.arange(0, n_epochs)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("Training and val loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="lower left")
plt.savefig("loss.png")

# %%
# plot the learning rate vs training iterations
N = np.arange(0, len(clr.history["lr"]))
plt.figure()
plt.plot(N, clr.history["lr"])
plt.title("Cyclical Learning Rate (CLR)")
plt.xlabel("Training Iterations")
plt.ylabel("Learning Rate")
plt.savefig("clr_plot.png")

# %%
# plot learning rate vs number of epochs
import os
perEpoch = np.arange(0, n_epochs)
cyclicLR = []
clr_all_iter = clr.history["lr"]
for ind in range(len(clr_all_iter)):
    if ind % steps_per_epoch==0:
        cyclicLR.append(clr_all_iter[ind])

plt.figure()
plt.plot(perEpoch, cyclicLR)
plt.title("Cyclical Learning Rate (CLR)")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate")
plt.savefig("clr_epochs.png")
