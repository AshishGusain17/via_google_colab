# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishGusain17/via_google_colab/blob/master/kaggle_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !ls
# Out:
# sample_data

# %%
# !mkdir .kaggle

# %%
import json
token = {"username":"ashishgusain2017","key":"5e6b1327873206c0633e5a4f95f70033"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json

# %%
# !kaggle config set -n path -v{/content}
# Out:
# ...
# - path is now set to: {/content}

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                            title                                                size  lastUpdated          downloadCount
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge              COVID-19 Open Research Dataset Challenge (CORD-19)    1GB  2020-04-17 22:02:37          52983
# roche-data-science-coalition/uncover                           UNCOVER COVID-19 Challenge                          123MB  2020-04-08 22:04:30           3996
# praveengovi/coronahack-chest-xraydataset                       CoronaHack -Chest X-Ray-Dataset                       1GB  2020-03-20 01:26:40            615
# katerpillar/meteonet                                           MeteoNet North-West France                           11GB  2020-04-16 08:35:45             44
# ...

# %%
# !kaggle datasets list -s sentiment
# Out:
# ...
# ref                                                    title                                          size  lastUpdated          downloadCount
# -----------------------------------------------------  --------------------------------------------  -----  -------------------  -------------
# crowdflower/twitter-airline-sentiment                  Twitter US Airline Sentiment                    3MB  2019-10-16 00:04:05          38119
# harriken/emoji-sentiment                               Emoji sentiment                                12MB  2017-10-01 09:56:54           2345
# kazanova/sentiment140                                  Sentiment140 dataset with 1.6 million tweets   81MB  2017-09-13 22:43:19          27757
# bittlingmayer/amazonreviews                            Amazon Reviews for Sentiment Analysis         493MB  2019-11-18 02:50:34          23509
# ...

# %%
# !kaggle datasets download -d allen-institute-for-ai/CORD-19-research-challenge
# Out:
# ...
#  99% 1.48G/1.50G [00:14<00:00, 106MB/s]
# 100% 1.50G/1.50G [00:14<00:00, 108MB/s]

# %%
# !unzip /content/{/content}/datasets/allen-institute-for-ai/CORD-19-research-challenge/CORD-19-research-challenge.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: custom_license/custom_license/pmc_json/PMC7123857.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123858.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123859.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123861.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123863.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123865.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123870.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123872.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123875.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123877.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123878.xml.json
#   inflating: custom_license/custom_license/pmc_json/PMC7123881.xml.json
# ...
