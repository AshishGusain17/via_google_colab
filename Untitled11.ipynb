# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishGusain17/via_google_colab/blob/master/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tensorflow/models
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 33758, done.
# remote: Total 33758 (delta 0), reused 0 (delta 0), pack-reused 33758
# Receiving objects: 100% (33758/33758), 511.99 MiB | 35.70 MiB/s, done.
# Resolving deltas: 100% (21608/21608), done.
# Checking out files: 100% (3194/3194), done.

# %%
# %ls
# %cd content
# Out:
# models/  protoc.exe  sample_data/

# %%
# protoc /models/research/object_detection/protos/*.proto --python_out=.
# Out:
#   File "<ipython-input-10-ccae890743fe>", line 1
#     protoc /models/research/object_detection/protos/*.proto --python_out=.
#                                                     ^
# SyntaxError: invalid syntax

# %%
import os
import sys
args = sys.argv
directory = '/content/models/research/object_detection/protos'
protoc_path = '/content/protoc'
for file in os.listdir(directory):
    if file.endswith(".proto"):
        os.system(protoc_path+" "+directory+"/"+file+" --python_out=.")

# %%
# %cd content
# Out:
# /content

# %%
# !apt-get install protobuf-compiler python-pil python-lxml python-tk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-tk is already the newest version (2.7.17-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   python-bs4 python-chardet python-html5lib python-olefile
#   python-pkg-resources python-six python-webencodings
# Suggested packages:
#   python-genshi python-lxml-dbg python-lxml-doc python-pil-doc python-pil-dbg
#   python-setuptools
# The following NEW packages will be installed:
#   python-bs4 python-chardet python-html5lib python-lxml python-olefile
#   python-pil python-pkg-resources python-six python-webencodings
# 0 upgraded, 9 newly installed, 0 to remove and 7 not upgraded.
# Need to get 1,818 kB of archives.
# ...

# %%
# %cd content/models/research
# !export PYTHONPATH=$PYTHONPATH:/content/models/research/object_detection:/content/models/research/object_detection/slim 
# %set_env PYTHONPATH=/content/models/research:/content/models/research/slim
# %cd object_detection
# !python train.py --logtostderr --train_dir=training --pipeline_config_path=training/faster_rcnn_inception_v2_pets.config
# %cd ..
# %cd ..
# %cd ..
# %cd ..
# Out:
# /content/models/research
# env: PYTHONPATH=/content/models/research:/content/models/research/slim
# /content/models/research/object_detection
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/inception_resnet_v2.py:374: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /content/models/research/slim/nets/mobilenet/mobilenet.py:397: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# ...

# %%
# %cd models/research
# !protoc object_detection/protos/*.proto — python_out=.
# Out:
# /content/models/research
# Missing output directives.

# %%
# %cd /content
# %ls
# %cd ..
# Out:
# /content
# models/  protoc.exe  sample_data/
# /

# %%
# !python setup.py build
# Out:
# running build
# running build_py
# creating build
# creating build/lib
# creating build/lib/object_detection
# copying object_detection/model_lib_test.py -> build/lib/object_detection
# copying object_detection/model_hparams.py -> build/lib/object_detection
# copying object_detection/model_main.py -> build/lib/object_detection
# copying object_detection/inputs_test.py -> build/lib/object_detection
# copying object_detection/eval_util.py -> build/lib/object_detection
# copying object_detection/model_lib.py -> build/lib/object_detection
# copying object_detection/eval_util_test.py -> build/lib/object_detection
# copying object_detection/exporter.py -> build/lib/object_detection
# copying object_detection/export_tflite_ssd_graph_lib.py -> build/lib/object_detection
# copying object_detection/model_tpu_main.py -> build/lib/object_detection
# copying object_detection/model_lib_v2_test.py -> build/lib/object_detection
# ...

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing object_detection.egg-info/PKG-INFO
# writing dependency_links to object_detection.egg-info/dependency_links.txt
# writing requirements to object_detection.egg-info/requires.txt
# writing top-level names to object_detection.egg-info/top_level.txt
# writing manifest file 'object_detection.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/object_detection
# creating build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/box_predictor_builder.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# copying build/lib/object_detection/builders/anchor_generator_builder_test.py -> build/bdist.linux-x86_64/egg/object_detection/builders
# ...

# %%
# %ls
# %cd object_detection
# Out:
# a3c_blogpost/                      lm_1b/
# adversarial_crypto/                lm_commonsense/
# adversarial_logit_pairing/         lstm_object_detection/
# adversarial_text/                  marco/
# adv_imagenet_models/               maskgan/
# astronet/                          morph_net/
# attention_ocr/                     namignizer/
# audioset/                          neural_gpu/
# autoaugment/                       neural_programmer/
# autoencoder/                       next_frame_prediction/
# brain_coder/                       nst_blogpost/
# build/                             object_detection/
# cognitive_mapping_and_planning/    object_detection.egg-info/
# cognitive_planning/                pcl_rl/
# compression/                       ptn/
# cvt_text/                          qa_kg/
# deep_contextual_bandits/           README.md
# deeplab/                           real_nvp/
# deep_speech/                       rebar/
# delf/                              resnet/
# ...

# %%
# %cd models/research/object_detection
# !python train.py --logtostderr --train_dir=training --pipeline_config_path=training/faster_rcnn_inception_v2_pets.config
# Out:
# /content/models/research/object_detection
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Traceback (most recent call last):
#   File "train.py", line 52, in <module>
#     from object_detection.builders import model_builder
#   File "/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/object_detection/builders/model_builder.py", line 20, in <module>
#     from object_detection.builders import anchor_generator_builder
#   File "/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/object_detection/builders/anchor_generator_builder.py", line 22, in <module>
# ...

# %%
PYTHONPATH /content/models/research /content/models/research/slim /content/models/research/object_detection
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-6c768c7e470d> in <module>()
# ----> 1 PYTHONPATH /content/models/research /content/models/research/slim /content/models/research/object_detection
#
# NameError: name 'PYTHONPATH' is not defined
