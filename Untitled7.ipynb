# %% [markdown]
# <a href="https://colab.research.google.com/github/AshishGusain17/via_google_colab/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import pandas as pd
import os,shutil,math,scipy,cv2
import numpy as np
import matplotlib.pyplot as plt
import random as rn
import imutils

from sklearn.utils import shuffle
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix,roc_curve,auc

from PIL import Image
from PIL import Image as pil_image
from PIL import ImageDraw

from time import time
from glob import glob
from tqdm import tqdm
from skimage.io import imread
from IPython.display import SVG
from skimage.transform import pyramid_gaussian

from scipy import misc,ndimage
from scipy.ndimage.interpolation import zoom
# from scipy.ndimage import imread

import keras
from keras import backend as K
from keras.utils.np_utils import to_categorical
from keras import layers
from keras.preprocessing.image import save_img
from keras.utils.vis_utils import model_to_dot
from keras.applications.vgg16 import VGG16,preprocess_input
from keras.models import Sequential,Input,Model
from keras.layers import Dense,Flatten,Dropout,Concatenate,GlobalAveragePooling2D,Lambda,ZeroPadding2D
from keras.layers import SeparableConv2D,BatchNormalization,MaxPooling2D,Conv2D
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam,SGD
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint,EarlyStopping,TensorBoard,CSVLogger,ReduceLROnPlateau,LearningRateScheduler
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
def get_iou(bb1, bb2):
    assert bb1['x1'] < bb1['x2']
    assert bb1['y1'] < bb1['y2']
    assert bb2['x1'] < bb2['x2']
    assert bb2['y1'] < bb2['y2']
    x_left = max(bb1['x1'], bb2['x1'])
    y_top = max(bb1['y1'], bb2['y1'])
    x_right = min(bb1['x2'], bb2['x2'])
    y_bottom = min(bb1['y2'], bb2['y2'])
    if x_right < x_left or y_bottom < y_top:
        return 0.0
    intersection_area = (x_right - x_left) * (y_bottom - y_top)
    bb1_area = (bb1['x2'] - bb1['x1']) * (bb1['y2'] - bb1['y1'])
    bb2_area = (bb2['x2'] - bb2['x1']) * (bb2['y2'] - bb2['y1'])
    iou = intersection_area / float(bb1_area + bb2_area - intersection_area)
    assert iou >= 0.0
    assert iou <= 1.0
    return iou

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_images=[]
train_labels=[]
img=cv2.imread('/content/images (10).jpg',cv2.IMREAD_COLOR)
image=cv2.resize(img,(224,224)).reshape(224,224,3)
annot='/content/drive/My Drive/rcnn/Airplanes_Annotations'
path='/content/drive/My Drive/rcnn/Images'
for e,i in enumerate(os.listdir(annot)):
    try:
        if i.startswith("airplane"):
            filename = i.split(".")[0]+".jpg"
            print(e,filename)
            image = cv2.imread(os.path.join(path,filename))
            df = pd.read_csv(os.path.join(annot,i))
            gtvalues=[]
            for row in df.iterrows():
                x1 = int(row[1][0].split(" ")[0])
                y1 = int(row[1][0].split(" ")[1])
                x2 = int(row[1][0].split(" ")[2])
                y2 = int(row[1][0].split(" ")[3])
                gtvalues.append({"x1":x1,"x2":x2,"y1":y1,"y2":y2})
            ss.setBaseImage(image)
            ss.switchToSelectiveSearchFast()
            ssresults = ss.process()
            imout = image.copy()
            counter = 0
            falsecounter = 0
            flag = 0
            fflag = 0
            bflag = 0
            for e,result in enumerate(ssresults):
                if e < 2000 and flag == 0:
                    for gtval in gtvalues:
                        x,y,w,h = result
                        iou = get_iou(gtval,{"x1":x,"x2":x+w,"y1":y,"y2":y+h})
                        if counter < 30:
                            if iou > 0.70:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(1)
                                counter += 1
                        else :
                            fflag =1
                        if falsecounter <30:
                            if iou < 0.3:
                                timage = imout[y:y+h,x:x+w]
                                resized = cv2.resize(timage, (224,224), interpolation = cv2.INTER_AREA)
                                train_images.append(resized)
                                train_labels.append(0)
                                falsecounter += 1
                        else :
                            bflag = 1
                    if fflag == 1 and bflag == 1:
                        print("inside")
                        flag = 1
    except Exception as e:
        print(e)
        print("error in "+filename)
        continue
# Out:
# 0 airplane_494.jpg
# 1 airplane_489.jpg
# 2 airplane_497.jpg
# inside
# 3 airplane_488.jpg
# 4 airplane_487.jpg
# inside
# 5 airplane_480.jpg
# 6 airplane_482.jpg
# 7 airplane_483.jpg
# 8 airplane_478.jpg
# 9 airplane_484.jpg
# 10 airplane_481.jpg
# 11 airplane_479.jpg
# 12 airplane_485.jpg
# 13 airplane_486.jpg
# 14 airplane_477.jpg
# 15 airplane_476.jpg
# 16 airplane_472.jpg
# 17 airplane_466.jpg
# 18 airplane_467.jpg
# 19 airplane_468.jpg
# 20 airplane_470.jpg
# 21 airplane_471.jpg
# 22 airplane_469.jpg
# inside
# 23 airplane_475.jpg
# 24 airplane_473.jpg
# 25 airplane_474.jpg
# 26 airplane_465.jpg
# 27 airplane_464.jpg
# 28 airplane_461.jpg
# 29 airplane_458.jpg
# 30 airplane_460.jpg
# 31 airplane_454.jpg
# 32 airplane_459.jpg
# 33 airplane_457.jpg
# 34 airplane_456.jpg
# 35 airplane_463.jpg
# 36 airplane_455.jpg
# 37 airplane_462.jpg
# 38 airplane_453.jpg
# 39 airplane_452.jpg
# inside
# 40 airplane_449.jpg
# 41 airplane_447.jpg
# 42 airplane_450.jpg
# 43 airplane_448.jpg
# 44 airplane_445.jpg
# 45 airplane_443.jpg
# 46 airplane_446.jpg
# 47 airplane_444.jpg
# 48 airplane_451.jpg
# 49 airplane_442.jpg
# 50 airplane_441.jpg
# 51 airplane_431.jpg
# 52 airplane_437.jpg
# 53 airplane_436.jpg
# 54 airplane_435.jpg
# 55 airplane_433.jpg
# 56 airplane_434.jpg
# inside
# 57 airplane_438.jpg
# 58 airplane_440.jpg
# 59 airplane_432.jpg
# 60 airplane_439.jpg
# 61 airplane_430.jpg
# 62 airplane_429.jpg
# 63 airplane_425.jpg
# 64 airplane_419.jpg
# inside
# 65 airplane_423.jpg
# 66 airplane_424.jpg
# 67 airplane_422.jpg
# 68 airplane_426.jpg
# 69 airplane_421.jpg
# 70 airplane_428.jpg
# 71 airplane_420.jpg
# 72 airplane_427.jpg
# inside
# 73 airplane_418.jpg
# 74 airplane_417.jpg
# 75 airplane_408.jpg
# 76 airplane_413.jpg
# 77 airplane_409.jpg
# 78 airplane_411.jpg
# 79 airplane_412.jpg
# 80 airplane_407.jpg
# 81 airplane_414.jpg
# 82 airplane_416.jpg
# 83 airplane_410.jpg
# 84 airplane_415.jpg
# 85 airplane_406.jpg
# 86 airplane_405.jpg
# 87 airplane_400.jpg
# 88 airplane_398.jpg
# 89 airplane_399.jpg
# 90 airplane_401.jpg
# 91 airplane_397.jpg
# 92 airplane_396.jpg
# 93 airplane_402.jpg
# 94 airplane_403.jpg
# 95 airplane_404.jpg
# 96 airplane_395.jpg
# 97 airplane_394.jpg
# 98 airplane_388.jpg
# inside
# 99 airplane_393.jpg
# 100 airplane_392.jpg
# 101 airplane_390.jpg
# 102 airplane_391.jpg
# 103 airplane_387.jpg
# 104 airplane_386.jpg
# 105 airplane_389.jpg
# 106 airplane_384.jpg
# 107 airplane_385.jpg
# inside
# 108 airplane_379.jpg
# 109 airplane_376.jpg
# 110 airplane_381.jpg
# 111 airplane_374.jpg
# 112 airplane_377.jpg
# inside
# 113 airplane_380.jpg
# 114 airplane_378.jpg
# 115 airplane_383.jpg
# inside
# 116 airplane_560.jpg
# 117 airplane_568.jpg
# inside
# 118 airplane_559.jpg
# 119 airplane_558.jpg
# 120 airplane_550.jpg
# 121 airplane_549.jpg
# 122 airplane_551.jpg
# inside
# 123 airplane_548.jpg
# 124 airplane_555.jpg
# inside
# 125 airplane_554.jpg
# 126 airplane_552.jpg
# 127 airplane_557.jpg
# 128 airplane_553.jpg
# inside
# 129 airplane_556.jpg
# 130 airplane_547.jpg
# 131 airplane_546.jpg
# 132 airplane_539.jpg
# 133 airplane_538.jpg
# 134 airplane_540.jpg
# 135 airplane_541.jpg
# 136 airplane_537.jpg
# 137 airplane_536.jpg
# 138 airplane_542.jpg
# 139 airplane_545.jpg
# 140 airplane_543.jpg
# 141 airplane_544.jpg
# 142 airplane_535.jpg
# 143 airplane_534.jpg
# 144 airplane_527.jpg
# 145 airplane_532.jpg
# 146 airplane_526.jpg
# inside
# 147 airplane_528.jpg
# 148 airplane_530.jpg
# 149 airplane_525.jpg
# 150 airplane_529.jpg
# 151 airplane_531.jpg
# 152 airplane_533.jpg
# 153 airplane_524.jpg
# 154 airplane_523.jpg
# 155 airplane_516.jpg
# 156 airplane_517.jpg
# 157 airplane_515.jpg
# 158 airplane_514.jpg
# 159 airplane_519.jpg
# 160 airplane_518.jpg
# 161 airplane_513.jpg
# 162 airplane_522.jpg
# 163 airplane_520.jpg
# 164 airplane_521.jpg
# 165 airplane_512.jpg
# 166 airplane_511.jpg
# 167 airplane_504.jpg
# inside
# 168 airplane_506.jpg
# 169 airplane_503.jpg
# 170 airplane_502.jpg
# 171 airplane_507.jpg
# 172 airplane_505.jpg
# 173 airplane_501.jpg
# 174 airplane_510.jpg
# 175 airplane_508.jpg
# 176 airplane_509.jpg
# 177 airplane_500.jpg
# 178 airplane_499.jpg
# 179 airplane_490.jpg
# 180 airplane_491.jpg
# 181 airplane_495.jpg
# 182 airplane_493.jpg
# 183 airplane_492.jpg
# 184 airplane_496.jpg
# 185 airplane_498.jpg
# 186 airplane_667.jpg
# 187 airplane_673.jpg
# 188 airplane_664.jpg
# 189 airplane_663.jpg
# 190 airplane_661.jpg
# 191 airplane_656.jpg
# 192 airplane_657.jpg
# 193 airplane_662.jpg
# 194 airplane_659.jpg
# 195 airplane_658.jpg
# inside
# 196 airplane_655.jpg
# 197 airplane_652.jpg
# 198 airplane_653.jpg
# 199 airplane_654.jpg
# 200 airplane_660.jpg
# 201 airplane_651.jpg
# 202 airplane_650.jpg
# 203 airplane_645.jpg
# inside
# 204 airplane_641.jpg
# 205 airplane_642.jpg
# 206 airplane_644.jpg
# 207 airplane_647.jpg
# 208 airplane_640.jpg
# 209 airplane_643.jpg
# 210 airplane_649.jpg
# 211 airplane_646.jpg
# 212 airplane_648.jpg
# 213 airplane_639.jpg
# 214 airplane_638.jpg
# inside
# 215 airplane_630.jpg
# 216 airplane_632.jpg
# 217 airplane_635.jpg
# 218 airplane_631.jpg
# 219 airplane_628.jpg
# 220 airplane_634.jpg
# 221 airplane_629.jpg
# 222 airplane_633.jpg
# 223 airplane_637.jpg
# 224 airplane_627.jpg
# 225 airplane_636.jpg
# 226 airplane_626.jpg
# 227 airplane_621.jpg
# inside
# 228 airplane_618.jpg
# 229 airplane_616.jpg
# inside
# 230 airplane_617.jpg
# 231 airplane_619.jpg
# inside
# 232 airplane_623.jpg
# 233 airplane_622.jpg
# 234 airplane_625.jpg
# 235 airplane_620.jpg
# 236 airplane_624.jpg
# inside
# 237 airplane_615.jpg
# 238 airplane_614.jpg
# 239 airplane_609.jpg
# 240 airplane_611.jpg
# 241 airplane_612.jpg
# 242 airplane_610.jpg
# 243 airplane_606.jpg
# 244 airplane_608.jpg
# 245 airplane_613.jpg
# 246 airplane_607.jpg
# 247 airplane_605.jpg
# 248 airplane_604.jpg
# 249 airplane_597.jpg
# 250 airplane_599.jpg
# 251 airplane_596.jpg
# inside
# 252 airplane_603.jpg
# 253 airplane_602.jpg
# 254 airplane_600.jpg
# 255 airplane_598.jpg
# 256 airplane_601.jpg
# 257 airplane_594.jpg
# 258 airplane_595.jpg
# 259 airplane_585.jpg
# 260 airplane_589.jpg
# 261 airplane_590.jpg
# inside
# 262 airplane_587.jpg
# 263 airplane_591.jpg
# 264 airplane_584.jpg
# 265 airplane_586.jpg
# 266 airplane_593.jpg
# inside
# 267 airplane_588.jpg
# 268 airplane_592.jpg
# 269 airplane_583.jpg
# 270 airplane_582.jpg
# 271 airplane_578.jpg
# 272 airplane_573.jpg
# 273 airplane_574.jpg
# 274 airplane_576.jpg
# 275 airplane_572.jpg
# 276 airplane_575.jpg
# 277 airplane_577.jpg
# 278 airplane_581.jpg
# 279 airplane_579.jpg
# 280 airplane_580.jpg
# 281 airplane_571.jpg
# 282 airplane_570.jpg
# 283 airplane_564.jpg
# 284 airplane_563.jpg
# 285 airplane_565.jpg
# 286 airplane_566.jpg
# 287 airplane_561.jpg
# inside
# 288 airplane_567.jpg
# 289 airplane_562.jpg
# 290 airplane_569.jpg
# 302 airplane_700.jpg
# 308 airplane_699.jpg
# 309 airplane_698.jpg
# 310 airplane_688.jpg
# 311 airplane_695.jpg
# 312 airplane_694.jpg
# 313 airplane_689.jpg
# 314 airplane_690.jpg
# 315 airplane_691.jpg
# 316 airplane_692.jpg
# 317 airplane_697.jpg
# 318 airplane_693.jpg
# 319 airplane_696.jpg
# 320 airplane_687.jpg
# 321 airplane_686.jpg
# 322 airplane_676.jpg
# 323 airplane_679.jpg
# 324 airplane_678.jpg
# 325 airplane_682.jpg
# 326 airplane_677.jpg
# 327 airplane_683.jpg
# 328 airplane_681.jpg
# 329 airplane_685.jpg
# 330 airplane_680.jpg
# 331 airplane_684.jpg
# 332 airplane_675.jpg
# 333 airplane_674.jpg
# 334 airplane_671.jpg
# 335 airplane_668.jpg
# 336 airplane_670.jpg
# 337 airplane_669.jpg
# 338 airplane_666.jpg
# 339 airplane_672.jpg
# 340 airplane_665.jpg
# 359 airplane_003.jpg
# 364 airplane_002.jpg
# 365 airplane_001.jpg
# inside
# 367 airplane_004.jpg
# inside
# 368 airplane_012.jpg
# inside
# 369 airplane_010.jpg
# 370 airplane_013.jpg
# 371 airplane_005.jpg
# inside
# 372 airplane_008.jpg
# 373 airplane_011.jpg
# 374 airplane_006.jpg
# 375 airplane_007.jpg
# inside
# 376 airplane_009.jpg
# 377 airplane_014.jpg
# 378 airplane_017.jpg
# 379 airplane_019.jpg
# 380 airplane_021.jpg
# 381 airplane_022.jpg
# 382 airplane_020.jpg
# 383 airplane_018.jpg
# 384 airplane_016.jpg
# 385 airplane_015.jpg
# 386 airplane_023.jpg
# 387 airplane_024.jpg
# 388 airplane_033.jpg
# 389 airplane_028.jpg
# 390 airplane_034.jpg
# 391 airplane_025.jpg
# 392 airplane_031.jpg
# 393 airplane_027.jpg
# 394 airplane_032.jpg
# 395 airplane_029.jpg
# 396 airplane_026.jpg
# 397 airplane_030.jpg
# 398 airplane_035.jpg
# 399 airplane_037.jpg
# 400 airplane_036.jpg
# 401 airplane_039.jpg
# 402 airplane_038.jpg
# 403 airplane_045.jpg
# inside
# 404 airplane_043.jpg
# 405 airplane_042.jpg
# 406 airplane_044.jpg
# 407 airplane_040.jpg
# 408 airplane_041.jpg
# inside
# 409 airplane_046.jpg
# 410 airplane_047.jpg
# 411 airplane_057.jpg
# 412 airplane_048.jpg
# 413 airplane_058.jpg
# 414 airplane_051.jpg
# 415 airplane_053.jpg
# inside
# 416 airplane_049.jpg
# 417 airplane_050.jpg
# 418 airplane_056.jpg
# 419 airplane_052.jpg
# 420 airplane_054.jpg
# 421 airplane_055.jpg
# 422 airplane_059.jpg
# 423 airplane_060.jpg
# 424 airplane_069.jpg
# 425 airplane_070.jpg
# 426 airplane_065.jpg
# 427 airplane_071.jpg
# 428 airplane_064.jpg
# 429 airplane_062.jpg
# inside
# 430 airplane_061.jpg
# 431 airplane_067.jpg
# 432 airplane_068.jpg
# 433 airplane_063.jpg
# 434 airplane_066.jpg
# 435 airplane_072.jpg
# 436 airplane_073.jpg
# 437 airplane_082.jpg
# 438 airplane_080.jpg
# 439 airplane_074.jpg
# 440 airplane_076.jpg
# 441 airplane_077.jpg
# 442 airplane_079.jpg
# 443 airplane_075.jpg
# inside
# 444 airplane_081.jpg
# 445 airplane_078.jpg
# 446 airplane_083.jpg
# inside
# 447 airplane_084.jpg
# 448 airplane_085.jpg
# inside
# 449 airplane_094.jpg
# 450 airplane_087.jpg
# 451 airplane_092.jpg
# 452 airplane_093.jpg
# 453 airplane_090.jpg
# 454 airplane_089.jpg
# 455 airplane_091.jpg
# 456 airplane_088.jpg
# 457 airplane_086.jpg
# 458 airplane_095.jpg
# 459 airplane_096.jpg
# inside
# 460 airplane_105.jpg
# 461 airplane_104.jpg
# 462 airplane_100.jpg
# 463 airplane_099.jpg
# 464 airplane_101.jpg
# 465 airplane_103.jpg
# 466 airplane_097.jpg
# inside
# 467 airplane_098.jpg
# 468 airplane_102.jpg
# 469 airplane_106.jpg
# 470 airplane_107.jpg
# 471 airplane_116.jpg
# 472 airplane_117.jpg
# 473 airplane_118.jpg
# 474 airplane_113.jpg
# 475 airplane_119.jpg
# inside
# 476 airplane_109.jpg
# 477 airplane_114.jpg
# 478 airplane_110.jpg
# 479 airplane_112.jpg
# inside
# 480 airplane_111.jpg
# 481 airplane_115.jpg
# 482 airplane_108.jpg
# inside
# 483 airplane_120.jpg
# inside
# 484 airplane_121.jpg
# inside
# 485 airplane_130.jpg
# 486 airplane_127.jpg
# 487 airplane_125.jpg
# 488 airplane_123.jpg
# inside
# 489 airplane_126.jpg
# inside
# 490 airplane_124.jpg
# 491 airplane_122.jpg
# 492 airplane_131.jpg
# 493 airplane_128.jpg
# 494 airplane_129.jpg
# 495 airplane_132.jpg
# 496 airplane_133.jpg
# 497 airplane_137.jpg
# inside
# 498 airplane_139.jpg
# 499 airplane_134.jpg
# 500 airplane_141.jpg
# 501 airplane_142.jpg
# 502 airplane_143.jpg
# 503 airplane_138.jpg
# 504 airplane_140.jpg
# 505 airplane_136.jpg
# inside
# 506 airplane_135.jpg
# 507 airplane_144.jpg
# 508 airplane_145.jpg
# 509 airplane_154.jpg
# 510 airplane_146.jpg
# 511 airplane_150.jpg
# 512 airplane_152.jpg
# 513 airplane_147.jpg
# 514 airplane_148.jpg
# 515 airplane_151.jpg
# inside
# 516 airplane_153.jpg
# 517 airplane_149.jpg
# 518 airplane_155.jpg
# 519 airplane_156.jpg
# 520 airplane_157.jpg
# 521 airplane_166.jpg
# 522 airplane_163.jpg
# 523 airplane_160.jpg
# 524 airplane_158.jpg
# 525 airplane_161.jpg
# 526 airplane_165.jpg
# 527 airplane_162.jpg
# 528 airplane_164.jpg
# 529 airplane_159.jpg
# 530 airplane_167.jpg
# 531 airplane_168.jpg
# 532 airplane_169.jpg
# 533 airplane_178.jpg
# 534 airplane_176.jpg
# 535 airplane_171.jpg
# 536 airplane_174.jpg
# 537 airplane_172.jpg
# 538 airplane_170.jpg
# 539 airplane_173.jpg
# 540 airplane_175.jpg
# 541 airplane_177.jpg
# 542 airplane_179.jpg
# 543 airplane_180.jpg
# 544 airplane_181.jpg
# 545 airplane_190.jpg
# inside
# 546 airplane_187.jpg
# 547 airplane_184.jpg
# 548 airplane_188.jpg
# 549 airplane_186.jpg
# 550 airplane_185.jpg
# 551 airplane_182.jpg
# 552 airplane_189.jpg
# 553 airplane_183.jpg
# 554 airplane_191.jpg
# 555 airplane_192.jpg
# 556 airplane_199.jpg
# inside
# 557 airplane_201.jpg
# 558 airplane_202.jpg
# 559 airplane_196.jpg
# 560 airplane_200.jpg
# 561 airplane_198.jpg
# 562 airplane_195.jpg
# 563 airplane_193.jpg
# 564 airplane_194.jpg
# 565 airplane_197.jpg
# 566 airplane_203.jpg
# 567 airplane_204.jpg
# 568 airplane_213.jpg
# inside
# 569 airplane_214.jpg
# inside
# 570 airplane_215.jpg
# 571 airplane_209.jpg
# 572 airplane_207.jpg
# 573 airplane_208.jpg
# 574 airplane_211.jpg
# 575 airplane_205.jpg
# 576 airplane_210.jpg
# 577 airplane_212.jpg
# 578 airplane_206.jpg
# 579 airplane_216.jpg
# 580 airplane_217.jpg
# 581 airplane_226.jpg
# 582 airplane_222.jpg
# 583 airplane_225.jpg
# inside
# 584 airplane_223.jpg
# inside
# 585 airplane_218.jpg
# 586 airplane_220.jpg
# 587 airplane_227.jpg
# 588 airplane_221.jpg
# 589 airplane_219.jpg
# 590 airplane_224.jpg
# 591 airplane_228.jpg
# 592 airplane_229.jpg
# 593 airplane_233.jpg
# 594 airplane_238.jpg
# 595 airplane_239.jpg
# 596 airplane_240.jpg
# 597 airplane_241.jpg
# 598 airplane_242.jpg
# 599 airplane_243.jpg
# 600 airplane_231.jpg
# 601 airplane_235.jpg
# 602 airplane_232.jpg
# 603 airplane_230.jpg
# 604 airplane_236.jpg
# 605 airplane_234.jpg
# 606 airplane_237.jpg
# 607 airplane_244.jpg
# 608 airplane_245.jpg
# 609 airplane_254.jpg
# 610 airplane_247.jpg
# 611 airplane_252.jpg
# 612 airplane_246.jpg
# 613 airplane_249.jpg
# 614 airplane_251.jpg
# 615 airplane_248.jpg
# 616 airplane_253.jpg
# 617 airplane_250.jpg
# 618 airplane_255.jpg
# 619 airplane_256.jpg
# 620 airplane_258.jpg
# 621 airplane_259.jpg
# 622 airplane_263.jpg
# 623 airplane_261.jpg
# 624 airplane_257.jpg
# 625 airplane_264.jpg
# inside
# 626 airplane_265.jpg
# 627 airplane_266.jpg
# 628 airplane_262.jpg
# 629 airplane_260.jpg
# 630 airplane_267.jpg
# 631 airplane_268.jpg
# 632 airplane_277.jpg
# 633 airplane_269.jpg
# 634 airplane_278.jpg
# 635 airplane_275.jpg
# 636 airplane_273.jpg
# 637 airplane_271.jpg
# 638 airplane_272.jpg
# 639 airplane_276.jpg
# inside
# 640 airplane_274.jpg
# 641 airplane_270.jpg
# 642 airplane_279.jpg
# 643 airplane_280.jpg
# 644 airplane_289.jpg
# inside
# 645 airplane_284.jpg
# 646 airplane_290.jpg
# 647 airplane_286.jpg
# 648 airplane_281.jpg
# 649 airplane_287.jpg
# 650 airplane_283.jpg
# 651 airplane_285.jpg
# 652 airplane_282.jpg
# 653 airplane_288.jpg
# 654 airplane_291.jpg
# inside
# 655 airplane_292.jpg
# 656 airplane_301.jpg
# inside
# 657 airplane_294.jpg
# 658 airplane_293.jpg
# 659 airplane_299.jpg
# 660 airplane_298.jpg
# 661 airplane_300.jpg
# 662 airplane_295.jpg
# 663 airplane_296.jpg
# 664 airplane_297.jpg
# inside
# 665 airplane_302.jpg
# 666 airplane_303.jpg
# 667 airplane_304.jpg
# 668 airplane_313.jpg
# 669 airplane_306.jpg
# inside
# 670 airplane_310.jpg
# 671 airplane_308.jpg
# 672 airplane_312.jpg
# 673 airplane_309.jpg
# 674 airplane_307.jpg
# 675 airplane_305.jpg
# inside
# 676 airplane_311.jpg
# 677 airplane_314.jpg
# 678 airplane_315.jpg
# inside
# 679 airplane_324.jpg
# 680 airplane_321.jpg
# 681 airplane_323.jpg
# 682 airplane_319.jpg
# 683 airplane_318.jpg
# 684 airplane_317.jpg
# 685 airplane_320.jpg
# 686 airplane_316.jpg
# 687 airplane_322.jpg
# 688 airplane_325.jpg
# 689 airplane_326.jpg
# inside
# 690 airplane_327.jpg
# 691 airplane_336.jpg
# 692 airplane_337.jpg
# 693 airplane_338.jpg
# inside
# 694 airplane_339.jpg
# 695 airplane_332.jpg
# inside
# 696 airplane_333.jpg
# 697 airplane_329.jpg
# 698 airplane_331.jpg
# 699 airplane_328.jpg
# inside
# 700 airplane_330.jpg
# 701 airplane_335.jpg
# 702 airplane_334.jpg
# 703 airplane_340.jpg
# 704 airplane_341.jpg
# 705 airplane_350.jpg
# 706 airplane_345.jpg
# 707 airplane_343.jpg
# inside
# 708 airplane_342.jpg
# 709 airplane_346.jpg
# 710 airplane_344.jpg
# 711 airplane_347.jpg
# inside
# 712 airplane_349.jpg
# 713 airplane_348.jpg
# 714 airplane_351.jpg
# 715 airplane_352.jpg
# 716 airplane_358.jpg
# 717 airplane_355.jpg
# 718 airplane_359.jpg
# 719 airplane_360.jpg
# 720 airplane_354.jpg
# 721 airplane_353.jpg
# 722 airplane_356.jpg
# 723 airplane_357.jpg
# 724 airplane_361.jpg
# 725 airplane_362.jpg
# inside
# 726 airplane_371.jpg
# 727 airplane_365.jpg
# 728 airplane_363.jpg
# 729 airplane_367.jpg
# 730 airplane_372.jpg
# 731 airplane_368.jpg
# 732 airplane_364.jpg
# 733 airplane_370.jpg
# 734 airplane_366.jpg
# 735 airplane_369.jpg
# 736 airplane_373.jpg
# inside
# 737 airplane_382.jpg
# inside
# 738 airplane_375.jpg

# %%
X_new = np.array(train_images)
y_new = np.array(train_labels)

# %%
print(X_new.shape,y_new.shape)
print(len(train_images),len(train_labels))
# Out:
# (30229, 224, 224, 3) (30229,)
# 30229 30229

# %%
from keras.layers import Dense
from keras import Model
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.applications.vgg16 import VGG16
vggmodel = VGG16(weights='imagenet', include_top=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 16s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %%
for layers in (vggmodel.layers)[:15]:
    print(layers)
    layers.trainable = False
X= vggmodel.layers[-2].output
predictions = Dense(2, activation="softmax")(X)
model_final = Model(input = vggmodel.input, output = predictions)
opt = Adam(lr=0.0001)
model_final.compile(loss = keras.losses.categorical_crossentropy, optimizer = opt, metrics=["accuracy"])
model_final.summary()
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7fabb886dbe0>
# <keras.layers.convolutional.Conv2D object at 0x7fabb886d7f0>
# <keras.layers.convolutional.Conv2D object at 0x7fabb886d1d0>
# <keras.layers.pooling.MaxPooling2D object at 0x7fabb90b20f0>
# <keras.layers.convolutional.Conv2D object at 0x7fabb85dbb38>
# <keras.layers.convolutional.Conv2D object at 0x7fabb85debe0>
# <keras.layers.pooling.MaxPooling2D object at 0x7fabb85e0710>
# <keras.layers.convolutional.Conv2D object at 0x7fabb85ef940>
# <keras.layers.convolutional.Conv2D object at 0x7fabb85f4208>
# <keras.layers.convolutional.Conv2D object at 0x7fabb85fa518>
# <keras.layers.pooling.MaxPooling2D object at 0x7fabb7d7e7f0>
# <keras.layers.convolutional.Conv2D object at 0x7fabb7d85fd0>
# <keras.layers.convolutional.Conv2D object at 0x7fabb7d8bcc0>
# <keras.layers.convolutional.Conv2D object at 0x7fabb7d91e48>
# <keras.layers.pooling.MaxPooling2D object at 0x7fabb7d9c438>
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 126,633,474
# Non-trainable params: 7,635,264
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
class MyLabelBinarizer(LabelBinarizer):
    def transform(self, y):
        Y = super().transform(y)
        if self.y_type_ == 'binary':
            return np.hstack((Y, 1-Y))
        else:
            return Y
    def inverse_transform(self, Y, threshold=None):
        if self.y_type_ == 'binary':
            return super().inverse_transform(Y[:, 0], threshold)
        else:
            return super().inverse_transform(Y, threshold)
lenc = MyLabelBinarizer()
Y =  lenc.fit_transform(y_new)
X_train, X_test , y_train, y_test = train_test_split(X_new,Y,test_size=0.10)

# %%
trdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
traindata = trdata.flow(x=X_train, y=y_train)
tsdata = ImageDataGenerator(horizontal_flip=True, vertical_flip=True, rotation_range=90)
testdata = tsdata.flow(x=X_test, y=y_test)
