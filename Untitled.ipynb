# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
data = h5py.File('food_dataset\g.h5', "r")

# %%
a = np.array(data["category"][:])
b = np.array(data["category_names"][:])
c = np.array(data["images"][:])

# %%
kk=np.array(data)
print(kk)

print(a.shape,b.shape,c.shape)
# img=c[5].reshape(32,32)
ind=43
# plt.imshow(c[ind].reshape(128,128))
plt.imshow(c[ind])

a[ind]>0
# Out:
# ['category' 'category_names' 'images']
# (1000, 101) (101,) (1000, 384, 384, 3)
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
import cv2
# import cv
color_img = cv2.cvtColor(c[ind], cv2.CV_GRAY2RGB)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-f2dbe4e89861> in <module>
#       1 import cv2
#       2 # import cv
# ----> 3 color_img = cv2.cvtColor(c[ind], cv2.CV_GRAY2RGB)
#
# AttributeError: module 'cv2.cv2' has no attribute 'CV_GRAY2RGB'
